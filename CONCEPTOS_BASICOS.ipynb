# %% [markdown]
# <a href="https://colab.research.google.com/github/valentinaovalle-bot/Conceptos-Basicos/blob/main/CONCEPTOS_BASICOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CONCEPTOS BASICOS **

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a sample DataFrame with 'ventas' and 'publicidad' with 1000 data points
data = {'publicidad': np.random.rand(1000) * 100,
        'ventas': np.random.rand(1000) * 500 + 100}
df = pd.DataFrame(data)

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['publicidad'], df['ventas'])
plt.title('Gráfica de Dispersión entre Ventas y Publicidad')
plt.xlabel('Publicidad')
plt.ylabel('Ventas')
plt.grid(True)
plt.show()

# %% [markdown]
# TIPOS DE VARIABLE

# %%
x=1 # entero
y=2.5 # float
nombre="Valentina" # string
apellido= "Rodriguez"
print((type)(x))
print((type)(y))
print((type)(nombre))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
resultados = x + y
print (resultados)
# Out:
# 3.5

# %%
nombre_completo = nombre + " " + apellido
print(nombre_completo)
# Out:
# Valentina Rodriguez

# %%
resultados = x + y
print("el resultado de la suma de x y y es:", resultados)
# Out:
# el resultado de la suma de x y y es: 3.5

# %%
# input
nombre = input("Ingrese su nombre:")
print ("Hola", nombre)
# Out:
# Ingrese su nombre:Valentina
# Hola Valentina

# %%
# round

x = 1.4567865456
print(round(x, 2))
# Out:
# 1.46

# %% [markdown]
# Crear un programa donde se solicita ingresar su nombre y su edad, que automaticamente imprima saludandolo y mencionando cuanto años tendra en 5 años mas.

# %%
nombre = input("ingrese su nombre: ")
print("hola", nombre)
edad = input( "ingrese su edad:")
edad =int(edad)

print("En 5 años tendrá", edad + 5)
# Out:
# ingrese su nombre: Valentina
# hola Valentina
# ingrese su edad:22
# En 5 años tendrá 27

# %% [markdown]
# ESTRUCTURAS DE DATOS

# %% [markdown]
# LISTAS

# %%
# Crear lista
mi_lista = [1, 2, 3, 4, 5]
print(mi_lista)
# Out:
# [1, 2, 3, 4, 5]

# %%
print (mi_lista[4])
# Out:
# 5

# %%
mi_lista.append(9)
print(mi_lista)
# Out:
# [1, 2, 3, 4, 5, 9]

# %%
Frutas = [ "manzana", "banana", "cereza"]
Frutas.append("mango")
print(Frutas)
# Out:
# ['manzana', 'banana', 'cereza', 'mango']

# %%
Frutas.remove("banana")
print(Frutas)
# Out:
# ['manzana', 'cereza', 'mango']

# %%
Frutas[0] = "Fresa"
print(Frutas)
# Out:
# ['Fresa', 'cereza', 'mango']

# %%
type(Frutas)
# Out:
# list

# %% [markdown]
# TUPLAS

# %%
mi_tupla = (1, 2, 3, 4, 5)
print(mi_tupla)
type(mi_tupla)
# Out:
# (1, 2, 3, 4, 5)
# tuple

# %% [markdown]
# DICCIONARIO

# %%
mi_diccionario = {"nombre": "Valentina", "edad": 22, "ciudad": "Villavicencio"}
print(mi_diccionario)
type(mi_diccionario)
# Out:
# {'nombre': 'Valentina', 'edad': 22, 'ciudad': 'Villavicencio'}
# dict

# %%
mi_diccionario["nombre"].append("Maria")
print(mi_diccionario)

# %% [markdown]
# ESTRUCTURA DE CONTROL DE FLUJO

# %%
x = input("Ingrese un múmero:")
x =int(X)
type(x)
# Out:
# Ingrese un múmero:40
# int

# %%
nota = input("Ingrese un número:")
nota = int(nota)

if nota >= 5:
   print("Aprobado")
else:
   print("Reprobado")
# Out:
# Ingrese un número:6
# Aprobado

# %%
edad = input("Ingrese su edad:")
edad = int(edad)
if edad < 2 :
  print("Infante")
elif edad >= 2 and edad <= 12:
  print("Niño")
elif edad >= 13 and edad < 17:
  print("Adolescente")
elif edad >= 18 and edad < 64:
  print("Adulto")
elif edad >= 65:
  print("Adulto Mayor")
# Out:
# Ingrese su edad:2
# Niño

# %% [markdown]
# BUCLES

# %% [markdown]
# toma una secuencia y va ejecuntando un codigo a la variale de la secuencia

# %%
# BUCLES FOR

frutas = ["manzana", "banana", "cereza"]
for fruta in frutas:
    print("Me gusta comer", fruta)
# Out:
# Me gusta comer manzana
# Me gusta comer banana
# Me gusta comer cereza

# %%
lista = [1, 2, 3, 4, 5]
for numero in lista:
    print(numero * 10)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
# ciclo while
contador = 0
while contador < 5:
  print (contador)
  contador += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# FUNCIONES

# %%
def saludo():
  print("hello amigo")

# %%
def holaConNombre(nombre):
  print("hola"+nombre+"!")

# %%
def sumatoria (numero1, numero2):
  resultado = numero1 + numero2
  return resultado

# %%
sumatoria (5,20)
# Out:
# 25

# %%
def areacirculo(radio):
  pi_value = 3.14159
  area = pi_value * radio ** 2
  return area

# %%
areacirculo(5)
# Out:
# 78.53975

# %%
def celsius_a_fahrenheit(celsius):

  fahrenheit = (celsius * 9/5) + 32
  return fahrenheit
celsius_a_fahrenheit(25)
# Out:
# 77.0

# %%
edad=input("ingrese su edad:")
edad = int(edad)

if edad<2:
  print("infante")
elif edad>=2 and edad <12:
  print ("niño")
elif edad>=13 and edad <17:
    print("adolescente")
elif edad>=18 and edad <64:
    print("adulto")
elif edad>=65:
    print("senior")
# Out:
# ingrese su edad:22
# adulto

# %% [markdown]
# LIBRERIAS

# %%
import pandas as pd

# Crear un DataFrame de ejemplo para una industria (por ejemplo, ventas)
data = {'Producto': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C'],
        'Mes': ['Enero', 'Enero', 'Enero', 'Febrero', 'Febrero', 'Febrero', 'Marzo', 'Marzo', 'Marzo'],
        'Ventas': [150, 200, 100, 180, 220, 120, 200, 250, 150],
        'Precio': [10, 15, 8, 10, 15, 8, 10, 15, 8]}

df_industria = pd.DataFrame(data)

# Mostrar el DataFrame
print(df_industria)
# Out:
#   Producto      Mes  Ventas  Precio
# 0        A    Enero     150      10
# 1        B    Enero     200      15
# 2        C    Enero     100       8
# 3        A  Febrero     180      10
# 4        B  Febrero     220      15
# 5        C  Febrero     120       8
# 6        A    Marzo     200      10
# 7        B    Marzo     250      15
# 8        C    Marzo     150       8
